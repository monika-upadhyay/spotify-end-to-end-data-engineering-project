# %%
pip install spotipy
# Out:
# Requirement already satisfied: spotipy in /opt/anaconda3/lib/python3.12/site-packages (2.25.1)
# Requirement already satisfied: redis>=3.5.3 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (5.2.1)
# Requirement already satisfied: requests>=2.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (2.32.3)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from spotipy) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests>=2.25.0->spotipy) (2024.8.30)
# Note: you may need to restart the kernel to use updated packages.

# %%
import spotipy

# %%
from spotipy.oauth2 import SpotifyClientCredentials

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="e825634d27c74708891a1cc0ab1ef517", client_secret="1c299245137d46278317b8149234da31")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %% [markdown]
# sp is an object here, but you can use everywhere that you have access to extract data from spotipy

# %%
playlist_link = "https://open.spotify.com/playlist/2bcSVCNr1AtyVrB3YP9dLl"

# %% [markdown]
# we are interested in 2bcSVCNr1AtyVrB3YP9dLl because this is playlist ID that we actually want

# %%
playlist_link.split('/')
# Out:
# ['https:', '', 'open.spotify.com', 'playlist', '2bcSVCNr1AtyVrB3YP9dLl']

# %%
playlist_link.split('/')[-1]
# Out:
# '2bcSVCNr1AtyVrB3YP9dLl'

# %%
playlist_URI = playlist_link.split('/')[-1]
playlist_URI
# Out:
# '2bcSVCNr1AtyVrB3YP9dLl'

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]
# Out:
# {'added_at': '2025-01-07T18:18:24Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31h2heqkhbdprnmmgswxfs3d6gym'},
#   'href': 'https://api.spotify.com/v1/users/31h2heqkhbdprnmmgswxfs3d6gym',
#   'id': '31h2heqkhbdprnmmgswxfs3d6gym',
#   'type': 'user',
#   'uri': 'spotify:user:31h2heqkhbdprnmmgswxfs3d6gym'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'album',
#    'href': 'https://api.spotify.com/v1/albums/75SlrAXlLbJN9LYJwlTJh6',
#    'id': '75SlrAXlLbJN9LYJwlTJh6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27379f4a87c23143f0abb14c279',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0279f4a87c23143f0abb14c279',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485179f4a87c23143f0abb14c279',
#      'width': 64}],
#    'name': 'Mismatched: Season 3 (Soundtrack from the Netflix Series)',
#    'release_date': '2024-12-03',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:75SlrAXlLbJN9LYJwlTJh6',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NbgKDsEHiPzZBZkqZGkXm'},
#      'href': 'https://api.spotify.com/v1/artists/0NbgKDsEHiPzZBZkqZGkXm',
#      'id': '0NbgKDsEHiPzZBZkqZGkXm',
#      'name': 'Mismatched - Cast',
#      'type': 'artist',
#      'uri': 'spotify:artist:0NbgKDsEHiPzZBZkqZGkXm'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/75SlrAXlLbJN9LYJwlTJh6'},
#    'total_tracks': 12},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hzngLO20cX5IGqT0hVv1G'},
#     'href': 'https://api.spotify.com/v1/artists/6hzngLO20cX5IGqT0hVv1G',
#     'id': '6hzngLO20cX5IGqT0hVv1G',
#     'name': 'Anurag Saikia',
#     'type': 'artist',
#     'uri': 'spotify:artist:6hzngLO20cX5IGqT0hVv1G'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2DFCHTDIA0t638a4mm37dK'},
#     'href': 'https://api.spotify.com/v1/artists/2DFCHTDIA0t638a4mm37dK',
#     'id': '2DFCHTDIA0t638a4mm37dK',
#     'name': 'Raj Shekhar',
#     'type': 'artist',
#     'uri': 'spotify:artist:2DFCHTDIA0t638a4mm37dK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0bRPtPZQkWHeG7MGk9eWlh'},
#     'href': 'https://api.spotify.com/v1/artists/0bRPtPZQkWHeG7MGk9eWlh',
#     'id': '0bRPtPZQkWHeG7MGk9eWlh',
#     'name': 'Romy',
#     'type': 'artist',
#     'uri': 'spotify:artist:0bRPtPZQkWHeG7MGk9eWlh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2780kFYuvbwSLPJZ5faEDw'},
#     'href': 'https://api.spotify.com/v1/artists/2780kFYuvbwSLPJZ5faEDw',
#     'id': '2780kFYuvbwSLPJZ5faEDw',
#     'name': 'Amarabha Banerjee',
#     'type': 'artist',
#     'uri': 'spotify:artist:2780kFYuvbwSLPJZ5faEDw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzrZDyL5gYiROkv27pYKx'},
#     'href': 'https://api.spotify.com/v1/artists/4gzrZDyL5gYiROkv27pYKx',
#     'id': '4gzrZDyL5gYiROkv27pYKx',
#     'name': 'Varun Jain',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzrZDyL5gYiROkv27pYKx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ojkMVHjuDZgDXSJy5qs2h'},
#     'href': 'https://api.spotify.com/v1/artists/4ojkMVHjuDZgDXSJy5qs2h',
#     'id': '4ojkMVHjuDZgDXSJy5qs2h',
#     'name': 'Madhubanti Bagchi',
#     'type': 'artist',
#     'uri': 'spotify:artist:4ojkMVHjuDZgDXSJy5qs2h'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0NbgKDsEHiPzZBZkqZGkXm'},
#     'href': 'https://api.spotify.com/v1/artists/0NbgKDsEHiPzZBZkqZGkXm',
#     'id': '0NbgKDsEHiPzZBZkqZGkXm',
#     'name': 'Mismatched - Cast',
#     'type': 'artist',
#     'uri': 'spotify:artist:0NbgKDsEHiPzZBZkqZGkXm'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 312857,
#   'external_ids': {'isrc': 'INT202405090'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3vCzLB6kS2lGcIpm1OOUsy'},
#   'href': 'https://api.spotify.com/v1/tracks/3vCzLB6kS2lGcIpm1OOUsy',
#   'id': '3vCzLB6kS2lGcIpm1OOUsy',
#   'name': 'Ishq Hai',
#   'popularity': 83,
#   'uri': 'spotify:track:3vCzLB6kS2lGcIpm1OOUsy',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
len(data['items'])
# Out:
# 64

# %%
data['items'][0]
# Out:
# {'added_at': '2025-01-07T18:18:24Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31h2heqkhbdprnmmgswxfs3d6gym'},
#   'href': 'https://api.spotify.com/v1/users/31h2heqkhbdprnmmgswxfs3d6gym',
#   'id': '31h2heqkhbdprnmmgswxfs3d6gym',
#   'type': 'user',
#   'uri': 'spotify:user:31h2heqkhbdprnmmgswxfs3d6gym'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'explicit': False,
#   'type': 'track',
#   'episode': False,
#   'track': True,
#   'album': {'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'SE',
#     'CH',
#     'TW',
#     'TR',
#     'UY',
#     'US',
#     'GB',
#     'AD',
#     'LI',
#     'MC',
#     'ID',
#     'JP',
#     'TH',
#     'VN',
#     'RO',
#     'IL',
#     'ZA',
#     'SA',
#     'AE',
#     'BH',
#     'QA',
#     'OM',
#     'KW',
#     'EG',
#     'MA',
#     'DZ',
#     'TN',
#     'JO',
#     'PS',
#     'IN',
#     'BY',
#     'KZ',
#     'MD',
#     'UA',
#     'AL',
#     'BA',
#     'HR',
#     'ME',
#     'MK',
#     'RS',
#     'SI',
#     'KR',
#     'BD',
#     'PK',
#     'LK',
#     'GH',
#     'KE',
#     'NG',
#     'TZ',
#     'UG',
#     'AG',
#     'AM',
#     'BS',
#     'BB',
#     'BZ',
#     'BT',
#     'BW',
#     'BF',
#     'CV',
#     'CW',
#     'DM',
#     'FJ',
#     'GM',
#     'GE',
#     'GD',
#     'GW',
#     'GY',
#     'HT',
#     'JM',
#     'KI',
#     'LS',
#     'LR',
#     'MW',
#     'MV',
#     'ML',
#     'MH',
#     'FM',
#     'NA',
#     'NR',
#     'NE',
#     'PW',
#     'PG',
#     'PR',
#     'WS',
#     'SM',
#     'ST',
#     'SN',
#     'SC',
#     'SL',
#     'SB',
#     'KN',
#     'LC',
#     'VC',
#     'SR',
#     'TL',
#     'TO',
#     'TT',
#     'TV',
#     'VU',
#     'AZ',
#     'BN',
#     'BI',
#     'KH',
#     'CM',
#     'TD',
#     'KM',
#     'GQ',
#     'SZ',
#     'GA',
#     'GN',
#     'KG',
#     'LA',
#     'MO',
#     'MR',
#     'MN',
#     'NP',
#     'RW',
#     'TG',
#     'UZ',
#     'ZW',
#     'BJ',
#     'MG',
#     'MU',
#     'MZ',
#     'AO',
#     'CI',
#     'DJ',
#     'ZM',
#     'CD',
#     'CG',
#     'LY',
#     'TJ',
#     'VE',
#     'ET',
#     'XK'],
#    'type': 'album',
#    'album_type': 'album',
#    'href': 'https://api.spotify.com/v1/albums/75SlrAXlLbJN9LYJwlTJh6',
#    'id': '75SlrAXlLbJN9LYJwlTJh6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27379f4a87c23143f0abb14c279',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0279f4a87c23143f0abb14c279',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485179f4a87c23143f0abb14c279',
#      'width': 64}],
#    'name': 'Mismatched: Season 3 (Soundtrack from the Netflix Series)',
#    'release_date': '2024-12-03',
#    'release_date_precision': 'day',
#    'uri': 'spotify:album:75SlrAXlLbJN9LYJwlTJh6',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0NbgKDsEHiPzZBZkqZGkXm'},
#      'href': 'https://api.spotify.com/v1/artists/0NbgKDsEHiPzZBZkqZGkXm',
#      'id': '0NbgKDsEHiPzZBZkqZGkXm',
#      'name': 'Mismatched - Cast',
#      'type': 'artist',
#      'uri': 'spotify:artist:0NbgKDsEHiPzZBZkqZGkXm'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/75SlrAXlLbJN9LYJwlTJh6'},
#    'total_tracks': 12},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6hzngLO20cX5IGqT0hVv1G'},
#     'href': 'https://api.spotify.com/v1/artists/6hzngLO20cX5IGqT0hVv1G',
#     'id': '6hzngLO20cX5IGqT0hVv1G',
#     'name': 'Anurag Saikia',
#     'type': 'artist',
#     'uri': 'spotify:artist:6hzngLO20cX5IGqT0hVv1G'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2DFCHTDIA0t638a4mm37dK'},
#     'href': 'https://api.spotify.com/v1/artists/2DFCHTDIA0t638a4mm37dK',
#     'id': '2DFCHTDIA0t638a4mm37dK',
#     'name': 'Raj Shekhar',
#     'type': 'artist',
#     'uri': 'spotify:artist:2DFCHTDIA0t638a4mm37dK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0bRPtPZQkWHeG7MGk9eWlh'},
#     'href': 'https://api.spotify.com/v1/artists/0bRPtPZQkWHeG7MGk9eWlh',
#     'id': '0bRPtPZQkWHeG7MGk9eWlh',
#     'name': 'Romy',
#     'type': 'artist',
#     'uri': 'spotify:artist:0bRPtPZQkWHeG7MGk9eWlh'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2780kFYuvbwSLPJZ5faEDw'},
#     'href': 'https://api.spotify.com/v1/artists/2780kFYuvbwSLPJZ5faEDw',
#     'id': '2780kFYuvbwSLPJZ5faEDw',
#     'name': 'Amarabha Banerjee',
#     'type': 'artist',
#     'uri': 'spotify:artist:2780kFYuvbwSLPJZ5faEDw'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4gzrZDyL5gYiROkv27pYKx'},
#     'href': 'https://api.spotify.com/v1/artists/4gzrZDyL5gYiROkv27pYKx',
#     'id': '4gzrZDyL5gYiROkv27pYKx',
#     'name': 'Varun Jain',
#     'type': 'artist',
#     'uri': 'spotify:artist:4gzrZDyL5gYiROkv27pYKx'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/4ojkMVHjuDZgDXSJy5qs2h'},
#     'href': 'https://api.spotify.com/v1/artists/4ojkMVHjuDZgDXSJy5qs2h',
#     'id': '4ojkMVHjuDZgDXSJy5qs2h',
#     'name': 'Madhubanti Bagchi',
#     'type': 'artist',
#     'uri': 'spotify:artist:4ojkMVHjuDZgDXSJy5qs2h'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/0NbgKDsEHiPzZBZkqZGkXm'},
#     'href': 'https://api.spotify.com/v1/artists/0NbgKDsEHiPzZBZkqZGkXm',
#     'id': '0NbgKDsEHiPzZBZkqZGkXm',
#     'name': 'Mismatched - Cast',
#     'type': 'artist',
#     'uri': 'spotify:artist:0NbgKDsEHiPzZBZkqZGkXm'}],
#   'disc_number': 1,
#   'track_number': 1,
#   'duration_ms': 312857,
#   'external_ids': {'isrc': 'INT202405090'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3vCzLB6kS2lGcIpm1OOUsy'},
#   'href': 'https://api.spotify.com/v1/tracks/3vCzLB6kS2lGcIpm1OOUsy',
#   'id': '3vCzLB6kS2lGcIpm1OOUsy',
#   'name': 'Ishq Hai',
#   'popularity': 83,
#   'uri': 'spotify:track:3vCzLB6kS2lGcIpm1OOUsy',
#   'is_local': False},
#  'video_thumbnail': {'url': None}}

# %%
data['items'][0]['track']

# %%
data['items'][0]['track']['album']['id']
# Out:
# '75SlrAXlLbJN9LYJwlTJh6'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Mismatched: Season 3 (Soundtrack from the Netflix Series)'

# %%
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-12-03'

# %%
data['items'][0]['track']['album']['total_tracks']
# Out:
# 12

# %%
data['items'][0]['track']['album']['external_urls']
# Out:
# {'spotify': 'https://open.spotify.com/album/75SlrAXlLbJN9LYJwlTJh6'}

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/75SlrAXlLbJN9LYJwlTJh6'

# %% [markdown]
# we did this for 1 album, we need to do for all albums, so we will run a loop

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_external_URLs = row['track']['album']['external_urls']
    album_info = {'album_id':album_id, 'album_name':album_name, 'album_release_date':album_release_date, 'album_total_tracks':album_total_tracks,'album_external_URLs':album_external_URLs}
    album_list.append(album_info)
album_list

# %%
data['items'][0]['track']['artists'][0]['id']
# Out:
# '6hzngLO20cX5IGqT0hVv1G'

# %%
artist_list = []
for i in data['items']:
    for key,value in i.items():
        if(key == 'track'):
            for artist in value['artists']:
                print(artist)

# %%
artist_list = []
for i in data['items']:
    for key,value in i.items():
        if(key == 'track'):
            for artist in value['artists']:
                artist_info = {'artist_id':artist['id'],'artist_name':artist['name'],'external_urls':artist['href']}
                artist_list.append(artist_info)
artist_list

# %% [markdown]
# #songs info, outside album and artists

# %%
# my version bcox artist id is an list
songs_list = []
for row in data['items']:
    song_added_at = row['added_at']
    song_duration_ms = row['track']['duration_ms']
    song_external_urls = row['track']['external_urls']['spotify']
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_popularity = row['track']['popularity']
    song_album_id = row['track']['album']['id']
    song_artist = []
    for artist in row['track']['artists']:
        song_artist.append(artist['id'])
    # song_artist_id = row['track']['artists'][0]['id']
    song_info = {'song_id':song_id,'song_name':song_name,'song_popularity':song_popularity,'song_duration_ms':song_duration_ms,
                 'song_added_at':song_added_at,'song_external_urls':song_external_urls, 'song_album_id':song_album_id,'song_artist_id':song_artist   }
    songs_list.append(song_info)
songs_list

# %%
#darshil version
songs_list = []
for row in data['items']:
    song_added_at = row['added_at']
    song_duration_ms = row['track']['duration_ms']
    song_external_urls = row['track']['external_urls']['spotify']
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_popularity = row['track']['popularity']
    song_album_id = row['track']['album']['id']
    song_artist_id = row['track']['artists'][0]['id']
    song_info = {'song_id':song_id,'song_name':song_name,'song_popularity':song_popularity,'song_duration_ms':song_duration_ms,
                 'song_added_at':song_added_at,'song_external_urls':song_external_urls, 'song_album_id':song_album_id,'song_artist_id':song_artist_id   }
    songs_list.append(song_info)
songs_list

# %%
import pandas as pd

# %%
album_df = pd.DataFrame(album_list)
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   album_id             64 non-null     object
#  1   album_name           64 non-null     object
#  2   album_release_date   64 non-null     object
#  3   album_total_tracks   64 non-null     int64
#  4   album_external_URLs  64 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.6+ KB

# %%
album_df['album_release_date'] = pd.to_datetime(album_release_date)
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   album_id             64 non-null     object
#  1   album_name           64 non-null     object
#  2   album_release_date   64 non-null     datetime64[ns]
#  3   album_total_tracks   64 non-null     int64
#  4   album_external_URLs  64 non-null     object
# dtypes: datetime64[ns](1), int64(1), object(3)
# memory usage: 2.6+ KB

# %%
artist_df = pd.DataFrame(artist_list)
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 174 entries, 0 to 173
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   artist_id      174 non-null    object
#  1   artist_name    174 non-null    object
#  2   external_urls  174 non-null    object
# dtypes: object(3)
# memory usage: 4.2+ KB

# %%
songs_df = pd.DataFrame(songs_list)
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   song_id             64 non-null     object
#  1   song_name           64 non-null     object
#  2   song_popularity     64 non-null     int64
#  3   song_duration_ms    64 non-null     int64
#  4   song_added_at       64 non-null     object
#  5   song_external_urls  64 non-null     object
#  6   song_album_id       64 non-null     object
#  7   song_artist_id      64 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 4.1+ KB

# %%
songs_df['song_added_at'] = pd.to_datetime(song_added_at)
songs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   song_id             64 non-null     object
#  1   song_name           64 non-null     object
#  2   song_popularity     64 non-null     int64
#  3   song_duration_ms    64 non-null     int64
#  4   song_added_at       64 non-null     datetime64[ns, UTC]
#  5   song_external_urls  64 non-null     object
#  6   song_album_id       64 non-null     object
#  7   song_artist_id      64 non-null     object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 4.1+ KB

# %%
album_df.head()
# Out:
#                  album_id                                         album_name  \
# 0  75SlrAXlLbJN9LYJwlTJh6  Mismatched: Season 3 (Soundtrack from the Netf...
# 1  1poClftP5T3zRcqpsxPPfW                         Raanjhan (From "Do Patti")
# 2  013jUXOfDFXnDMBetTdsiH                                         Lost;Found
# 3  2P2orRpVU0F2Z1HGTi7AiS                       Aaj Ki Raat (From "Stree 2")
# 4  4TjqdNmCG0IEbNKVfbxTBV                                              Sajna
#
#   album_release_date  album_total_tracks  \
# 0         2025-02-28                  12
# 1         2025-02-28                   1
# 2         2025-02-28                  14
# 3         2025-02-28                   1
# 4         2025-02-28                   1
#
#                                  album_external_URLs
# 0  {'spotify': 'https://open.spotify.com/album/75...
# 1  {'spotify': 'https://open.spotify.com/album/1p...
# 2  {'spotify': 'https://open.spotify.com/album/01...
# 3  {'spotify': 'https://open.spotify.com/album/2P...
# 4  {'spotify': 'https://open.spotify.com/album/4T...

# %%
artist_df.head()
# Out:
#                 artist_id        artist_name  \
# 0  6hzngLO20cX5IGqT0hVv1G      Anurag Saikia
# 1  2DFCHTDIA0t638a4mm37dK        Raj Shekhar
# 2  0bRPtPZQkWHeG7MGk9eWlh               Romy
# 3  2780kFYuvbwSLPJZ5faEDw  Amarabha Banerjee
# 4  4gzrZDyL5gYiROkv27pYKx         Varun Jain
#
#                                        external_urls
# 0  https://api.spotify.com/v1/artists/6hzngLO20cX...
# 1  https://api.spotify.com/v1/artists/2DFCHTDIA0t...
# 2  https://api.spotify.com/v1/artists/0bRPtPZQkWH...
# 3  https://api.spotify.com/v1/artists/2780kFYuvbw...
# 4  https://api.spotify.com/v1/artists/4gzrZDyL5gY...

# %%
songs_df.head()
# Out:
#                   song_id                     song_name  song_popularity  \
# 0  3vCzLB6kS2lGcIpm1OOUsy                      Ishq Hai               83
# 1  4vHRQnzGcKEtqsLH70tAms    Raanjhan (From "Do Patti")               83
# 2  1hlbywc8Jhl1FFqJxAMabE                          Ishq               76
# 3  5AnWrUzsrFgBvhn6dUElnr  Aaj Ki Raat (From "Stree 2")               78
# 4  3uWQkslzoaKzbtOAjQxWNr                         Sajna               75
#
#    song_duration_ms             song_added_at  \
# 0            312857 2025-03-07 16:41:38+00:00
# 1            240066 2025-03-07 16:41:38+00:00
# 2            224842 2025-03-07 16:41:38+00:00
# 3            228620 2025-03-07 16:41:38+00:00
# 4            224680 2025-03-07 16:41:38+00:00
#
#                                   song_external_urls           song_album_id  \
# 0  https://open.spotify.com/track/3vCzLB6kS2lGcIp...  75SlrAXlLbJN9LYJwlTJh6
# 1  https://open.spotify.com/track/4vHRQnzGcKEtqsL...  1poClftP5T3zRcqpsxPPfW
# 2  https://open.spotify.com/track/1hlbywc8Jhl1FFq...  013jUXOfDFXnDMBetTdsiH
# 3  https://open.spotify.com/track/5AnWrUzsrFgBvhn...  2P2orRpVU0F2Z1HGTi7AiS
# 4  https://open.spotify.com/track/3uWQkslzoaKzbtO...  4TjqdNmCG0IEbNKVfbxTBV
#
#            song_artist_id
# 0  6hzngLO20cX5IGqT0hVv1G
# 1  1SyKki7JI1AZNKwgNMkn25
# 2  05etL4pzWd6TSv1x5WrlG3
# 3  1mBydYMVBECdDmMfE2sEUO
# 4  2GoeZ0qOTt6kjsWW4eA6LS
